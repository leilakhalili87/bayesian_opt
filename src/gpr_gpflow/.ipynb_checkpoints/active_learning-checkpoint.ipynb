# %% [markdown]
# # How to apply customized kernel using gpflow
#
# In this code GPR is applied to predict the enery of 388 grain boundaries of olmsted database.
#
# The pairwise distances are calculated based on the octonion package.

# %%
import gpflow
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from gpflow.utilities import print_summary, positive
from gpflow.config import set_default_float, default_float, set_default_summary_fmt
from gpflow.ci_utils import ci_niter

set_default_float(np.float64)
set_default_summary_fmt("notebook")

plt.style.use("ggplot")
# %matplotlib inline
np.random.seed(10)

# %% [markdown]
# Choose input data
# - `N` number of all the gbs
#     - `N=388` for the olmsted database
#     - `N=297` for Dr. Patala's paper
# - `n_train` number of the gbs in the training datseet
# - `n_iter` number of the iterations in the active learning
# - `n_max` number of the gbs added to the training data set in each iteration. These gbs has the highest variance.

# %%
tf.config.run_functions_eagerly(True)
# define database '297' or '388'
N = 388

# define numbe rof training dataset
n_train = 100

n_iter = 1

n_max = 1

# %%
# Read the data
if N == 297:
    data_E = './data/297_energy.txt'
    data_pd = './data/297_octonion_pd.txt'
    data_axes = './data/sigma3_data.txt'
    if n_train > N:
        print('The numbe rof trainign datset should be smaller than 297')
else:
    data_E = './data/energy_olms.txt'
    data_pd = './data/pd_olms.txt'
    if n_train > N:
        print('The numbe rof trainign datset should be smaller than 388')

# %%
# a function to convert the data into spherical coordinates
# this works for N = 297
def ax2spher(ax):
    # all the vectors are normalized so r=1
    # theta is between 0, 2pi
    theta = np.arctan(ax[1]/ax[0])*180/np.pi # angle with z axis
    # phi is between 0 and pi
    phi = np.arccos(ax[2])*180/np.pi # angle with x axis
    return theta, phi

if N == 297:  
    data = np.loadtxt(data_axes)
    axes = data[:,0:3]

    n_axes = axes/np.linalg.norm(axes, axis=1, keepdims=True)
    n_data = len(n_axes)
    angles = np.zeros((n_data,2))
    for i in range(n_data):
        theta, phi = ax2spher(n_axes[i,:])
        angles[i] = np.array([theta, phi])
    print('Theta is in the range of:')
    range_theta = [np.min(angles[:,0]), np.max(angles[:,0])]
    print(range_theta)

    print('\nphi is in the range of:')
    range_phi = [np.min(angles[:,1]), np.max(angles[:,1])]
    print(range_phi)

# %% [markdown]
# Here I defined a new class for the our custom kernel named `GBKernel`. This kernel is inhereted from the `gpflow.kernels.Matern12`. Within this kernel the octonion distance is defined. The octonion distances are previously calculated using the Matlab code. In this function (`_octonion_dist`) the corresponding rows and vectors are extracted from the matlab output.

# %%
def _octonion_dist(X, X2):
    X = tf.reshape(X, [-1,1])
    pd = np.loadtxt(data_pd)
    X2 = tf.reshape(X2, [-1,1])
    dist0 = np.zeros((len(X), len(X2)))
    dist = tf.Variable(dist0) # Use variable 
    for i in range(len(X)):
        init_val = int(X[i].numpy())
        for j in range(len(X2)):
            fin_val = int(X2[j].numpy())
            dist0[i,j] = pd[init_val, fin_val]
    dist.assign(dist0)
    return dist

def _octonion_dist_single(X):
    X = tf.reshape(X, [-1,1])
    pd = np.loadtxt(data_pd)
    dist0 = np.zeros((len(X)))
    dist = tf.Variable(dist0) # Use variable 
    for i in range(len(X)):
        init_val = int(X[i].numpy())
        print(init_val)
        dist0[i] = pd[init_val, init_val]
    dist.assign(dist0)
    return dist

class GBKernel(gpflow.kernels.Kernel):
    """
    Isotropic RBF Kernel with Haversine distance instead of euclidean distance.
    Assumes 2 dimensional data, with columns [latitude, longitude] in degrees.
    """

    def __init__(self, lengthscales=1.0):
        super().__init__(active_dims=[0])
        self.variance = gpflow.Parameter(1.0, transform=positive())

    def K(self, X, X2=None):
        if X2 is None:
            X2 = X
        return self.variance * tf.exp(-_octonion_dist(X, X2))

    def K_diag(self, X):
        return self.variance * tf.exp(-_octonion_dist_single(X))

#     def _scaled_square_dist(self, X, X2):
#         """
#     The Matern 1/2 kernel. Functions drawn from a GP with this kernel are not
#     differentiable anywhere. The kernel equation is

#     k(r) = σ² exp{-r}

#     where:
#     r  is the Euclidean distance between the input points, scaled by the lengthscales parameter ℓ.
#     σ² is the variance parameter
#     """
#         if X2 is None:
#             X2 = X
# #         dist = tf.square(self._haversine_dist(X, X2) / self.lengthscales)
# #         dist = self.variance * tf.exp(-0.5 * self._octonion_dist(X, X2))
#         dist = self.variance * tf.exp(-self._octonion_dist(X, X2)/self.lengthscales)
#         print(dist)
#         return dist

# %% [markdown]
# First the data are imported from the text file. Then `n_train` data is added as the training data set. The rest of the data is considered as the test dataset.
#
# The GPR model is created and optimized. Then in each iteration, in total `n_iter` iterations,  the `n_max` grain boundaries with the highest variance is added to the training data set.

# %%
k = GBKernel()
# extract the data for the first run
Y_all = np.loadtxt(data_E)
id_all = np.linspace(0,N-1, N)

# I chose n_train gbs as training data set randomly
id_train = np.sort(np.random.choice(N, size=n_train, replace=False))
Y_train = Y_all[id_train].reshape(-1,1)
id_train = np.array(id_train, dtype=np.float64)

# I chose rest of the gbs as the test set
id_test = id_all[~np.in1d(id_all,id_train)].reshape(-1,1)
Y_test = Y_all[id_test.astype(int)].reshape(-1,1)
id_train = id_train.reshape(-1,1)
m = gpflow.models.GPR((id_train, Y_train), kernel=k)

opt = gpflow.optimizers.Scipy()
opt.minimize(m.training_loss, variables=m.trainable_variables)

mean, var = m.predict_y(id_test)

var_np  = var.numpy().reshape(-1)
new_gb_id = id_test[(-var_np).argsort()[:n_max]]


for i in range(n_iter):
    new = np.sort(new_gb_id).reshape(-1,1)
    id_train = np.sort(np.concatenate((new, id_train))).reshape(-1,1)
    Y_train = Y_all[id_train.astype(int)].reshape(-1,1)
    all_d = id_all.astype(int)
    train_d = id_train.astype(int)
    id_test = id_all[~np.in1d(all_d,train_d)].reshape(-1,1)
    id_test = np.array(id_test, dtype=np.float64)
    Y_test = Y_all[id_test.astype(int)].reshape(-1,1)
    
    m = gpflow.models.GPR((id_train, Y_train), kernel=k)
    opt = gpflow.optimizers.Scipy()
    opt.minimize(m.training_loss, variables=m.trainable_variables)

    mean, var = m.predict_y(id_test)

    var_np  = var.numpy().reshape(-1)
    new_gb_id = id_test[(-var_np).argsort()[:n_max]]
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-85-417bb5ebafa6> in <module>
#      16
#      17 opt = gpflow.optimizers.Scipy()
# ---> 18 opt.minimize(m.training_loss, variables=m.trainable_variables)
#      19
#      20 mean, var = m.predict_y(id_test)
#
# ~/.local/lib/python3.6/site-packages/gpflow/optimizers/scipy.py in minimize(self, closure, variables, method, step_callback, compile, **scipy_kwargs)
#      87
#      88         return scipy.optimize.minimize(
# ---> 89             func, initial_params, jac=True, method=method, **scipy_kwargs
#      90         )
#      91
#
# ~/.local/lib/python3.6/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     608     elif meth == 'l-bfgs-b':
#     609         return _minimize_lbfgsb(fun, x0, args, jac, bounds,
# --> 610                                 callback=callback, **options)
#     611     elif meth == 'tnc':
#     612         return _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#
# ~/.local/lib/python3.6/site-packages/scipy/optimize/lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, **unknown_options)
#     343             # until the completion of the current minimization iteration.
#     344             # Overwrite f and g:
# --> 345             f, g = func_and_grad(x)
#     346         elif task_str.startswith(b'NEW_X'):
#     347             # new iteration
#
# ~/.local/lib/python3.6/site-packages/scipy/optimize/lbfgsb.py in func_and_grad(x)
#     293     else:
#     294         def func_and_grad(x):
# --> 295             f = fun(x, *args)
#     296             g = jac(x, *args)
#     297             return f, g
#
# ~/.local/lib/python3.6/site-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     325     def function_wrapper(*wrapper_args):
#     326         ncalls[0] += 1
# --> 327         return function(*(wrapper_args + args))
#     328
#     329     return ncalls, function_wrapper
#
# ~/.local/lib/python3.6/site-packages/scipy/optimize/optimize.py in __call__(self, x, *args)
#      63     def __call__(self, x, *args):
#      64         self.x = numpy.asarray(x).copy()
# ---> 65         fg = self.fun(x, *args)
#      66         self.jac = fg[1]
#      67         return fg[0]
#
# ~/.local/lib/python3.6/site-packages/gpflow/optimizers/scipy.py in _eval(x)
#     109
#     110         def _eval(x: np.ndarray) -> Tuple[np.ndarray, np.ndarray]:
# --> 111             loss, grad = _tf_eval(tf.convert_to_tensor(x))
#     112             return loss.numpy().astype(np.float64), grad.numpy().astype(np.float64)
#     113
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     822     if RUN_FUNCTIONS_EAGERLY:
#     823       with trace.Trace(self._name, tf_function_call="eager"):
# --> 824         return self._python_function(*args, **kwds)
#     825
#     826     tracing_count = self.experimental_get_tracing_count()
#
# ~/.local/lib/python3.6/site-packages/gpflow/optimizers/scipy.py in _tf_eval(x)
#     102             cls.assign_tensors(variables, values)
#     103
# --> 104             loss, grads = _compute_loss_and_gradients(closure, variables)
#     105             return loss, cls.pack_tensors(grads)
#     106
#
# ~/.local/lib/python3.6/site-packages/gpflow/optimizers/scipy.py in _compute_loss_and_gradients(loss_closure, variables)
#     163     with tf.GradientTape(watch_accessed_variables=False) as tape:
#     164         tape.watch(variables)
# --> 165         loss = loss_closure()
#     166     grads = tape.gradient(loss, variables)
#     167     return loss, grads
#
# ~/.local/lib/python3.6/site-packages/gpflow/models/training_mixins.py in training_loss(self)
#      61         Returns the training loss for this model.
#      62         """
# ---> 63         return self._training_loss()
#      64
#      65     def training_loss_closure(self, *, compile=True) -> Callable[[], tf.Tensor]:
#
# ~/.local/lib/python3.6/site-packages/gpflow/models/model.py in _training_loss(self, *args, **kwargs)
#      55         adds the log density of all priors to maximum_log_likelihood_objective().
#      56         """
# ---> 57         return -(self.maximum_log_likelihood_objective(*args, **kwargs) + self.log_prior_density())
#      58
#      59     @abc.abstractmethod
#
# ~/.local/lib/python3.6/site-packages/gpflow/models/gpr.py in maximum_log_likelihood_objective(self)
#      63
#      64     def maximum_log_likelihood_objective(self) -> tf.Tensor:
# ---> 65         return self.log_marginal_likelihood()
#      66
#      67     def log_marginal_likelihood(self) -> tf.Tensor:
#
# ~/.local/lib/python3.6/site-packages/gpflow/models/gpr.py in log_marginal_likelihood(self)
#      79         s_diag = tf.fill([num_data], self.likelihood.variance)
#      80         ks = tf.linalg.set_diag(K, k_diag + s_diag)
# ---> 81         L = tf.linalg.cholesky(ks)
#      82         m = self.mean_function(X)
#      83
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/ops/gen_linalg_ops.py in cholesky(input, name)
#     773       return _result
#     774     except _core._NotOkStatusException as e:
# --> 775       _ops.raise_from_not_ok_status(e, name)
#     776     except _core._FallbackException:
#     777       pass
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in raise_from_not_ok_status(e, name)
#    6860   message = e.message + (" name: " + name if name is not None else "")
#    6861   # pylint: disable=protected-access
# -> 6862   six.raise_from(core._status_to_exception(e.code, message), None)
#    6863   # pylint: enable=protected-access
#    6864
#
# ~/.local/lib/python3.6/site-packages/six.py in raise_from(value, from_value)
#
# InvalidArgumentError: Cholesky decomposition was not successful. The input might not be valid. [Op:Cholesky]

# %% [markdown]
# Here I plotted the results.
#
# If `N=297` the results can be plotted based on `theta` (`plot_pref` = `out_ang1`) or `phi` (`plot_pref` = `out_ang2`).
#
# If `N=388` the plot is based on the id of the gb.

# %%
plot_pref = 'phi' # 'phi' or 'theta'

    
if N == 297:
    
    test_angle = np.zeros((len(id_test), 2))
    train_angle = np.zeros((len(id_train), 2))
    for i in range(len(id_test)):
        test_angle[i] = angles[int(i)]
    for i in range(len(id_train)):
        train_angle[i] = angles[int(i)]
    test_angle1 = test_angle[:,0].reshape(-1,1)
    train_angle1 = train_angle[:,0].reshape(-1,1)

    test_angle2 = test_angle[:,1].reshape(-1,1)
    train_angle2 = train_angle[:,1].reshape(-1,1)

    output_1 = np.stack([test_angle1, mean, var ], axis=0).reshape(3, len(test_angle1))
    out_ang1 = output_1[:, np.argsort(output_1[0, :])]

    output_2 = np.stack([test_angle2, mean, var ], axis=0).reshape(3, len(test_angle2))
    out_ang2 = output_2[:, np.argsort(output_2[0, :])]
    if plot_pref == 'phi':
        plot_pref = out_ang2
        train_pref = train_angle2
    else:
        plot_pref = out_ang1
        train_pref = train_angle1

    ## plot
    plt.figure(figsize=(8, 4))
    plt.plot(train_pref, Y_train, "kx", mew=2)
    plt.plot(plot_pref[0,:], plot_pref[1,:], "C0", lw=2)
    plt.fill_between(
        plot_pref[0,:],
        plot_pref[1, :] - 1.96 * np.sqrt(plot_pref[2,:]),
        plot_pref[1,:] + 1.96 * np.sqrt(plot_pref[2,:]),
        color="C0",
        alpha=0.2,
    )

    plt.xlabel('angle')
    plt.ylabel('energy')
else:
    ## plot
    plt.figure(figsize=(8, 4))
    plt.plot(id_train, Y_train, "kx", mew=2)
#     plt.plot(id_test, Y_test, "bo", mew=1)
    plt.plot(id_test, mean, "C0", lw=2)
    plt.fill_between(
        id_test[:, 0],
        mean[:, 0] - 1.96 * np.sqrt(var[:, 0]),
        mean[:, 0] + 1.96 * np.sqrt(var[:, 0]),
        color="C0",
        alpha=0.2,
    )

    plt.xlabel('id of the grain boundary')
    plt.ylabel('energy')

# %%
mean0, var0 = m.predict_y(id_train)
plt.figure(figsize=(12, 6))
plt.plot(mean0, Y_train, "kx", mew=2)
plt.plot(mean, Y_test, "rx", mew=2)
plt.xlabel('Predicted Energy values')
plt.ylabel('Actual Energy values')
# Out:
# Text(0, 0.5, 'Actual Energy values')

# %%
id_test.shape
# Out:
# (287, 1)

# %%
var_np.max()
# Out:
# 0.1284480524982274
